# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("chatgpt1.csv")

# %%
df
# Out:
#                         Datetime             Tweet Id  \
# 0      2023-01-22 13:44:34+00:00  1617156270871699456
# 1      2023-01-22 13:44:39+00:00  1617156291046133761
# 2      2023-01-22 13:44:44+00:00  1617156308926349312
# 3      2023-01-22 13:44:49+00:00  1617156332297256961
# 4      2023-01-22 13:44:52+00:00  1617156345064570880
# ...                          ...                  ...
# 49996  2023-01-24 06:57:56+00:00  1617778712082096128
# 49997  2023-01-24 06:57:59+00:00  1617778726393249792
# 49998  2023-01-24 06:58:00+00:00  1617778728481992705
# 49999  2023-01-24 06:58:01+00:00  1617778731678044162
# 50000  2023-01-24 06:58:01+00:00  1617778733355790342
#
#                                                     Text         Username  \
# 0      ChatGPTで遊ぶの忘れてた！！\n書類作るコード書いてみてほしいのと、\nどこまで思考整...      mochico0123
# 1      @AlexandrovnaIng Prohibition of ChatGPT has be...  Caput_LupinumSG
# 2      Schaut Euch an, was @fobizz @DianaKnodel alles...            ciffi
# ...

# %%
df.describe(include='all')
# Out:
#                          Datetime      Tweet Id               Text  \
# count                       50001  5.000100e+04              50001
# unique                      41559           NaN              49555
# top     2023-01-23 17:11:13+00:00           NaN  @chatgpt_issac AI
# freq                            8           NaN                164
# mean                          NaN  1.617493e+18                NaN
# std                           NaN  1.725682e+14                NaN
# min                           NaN  1.617156e+18                NaN
# 25%                           NaN  1.617354e+18                NaN
# 50%                           NaN  1.617525e+18                NaN
# 75%                           NaN  1.617625e+18                NaN
# max                           NaN  1.617779e+18                NaN
#
#               Username                                          Permalink  \
# count            50001                                              50001
# ...

# %%
df['Username'].value_counts()
# Out:
# translation_ja    60
# SaveToNotion      47
# trandanhmmo       44
# richardkimphd     43
# VeilleCyber3      38
#                   ..
# masayume_32        1
# WRoughSketch       1
# ayazfarooqui       1
# Technology_GD      1
# AmericoSD_69       1
# Name: Username, Length: 38433, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(15,6))
sns.countplot(data=df, x='Username',order=data.Username.value_counts().index[:20])
plt.xticks(rotation=90)
plt.show()

# %%
df['ReplyCount'].value_counts()
# Out:
# 0      36736
# 1       9430
# 2       1801
# 3        653
# 4        333
#        ...
# 45         1
# 147        1
# 106        1
# 166        1
# 331        1
# Name: ReplyCount, Length: 108, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(data=df, x='ReplyCount',order=data.ReplyCount.value_counts().index[:5])
plt.xticks(rotation=90)
plt.show()

# %%
df['RetweetCount'].value_counts()
# Out:
# 0      42416
# 1       3925
# 2       1204
# 3        620
# 4        365
#        ...
# 221        1
# 222        1
# 337        1
# 236        1
# 248        1
# Name: RetweetCount, Length: 138, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(data=df, x='RetweetCount',order=data.RetweetCount.value_counts().index[:5])
plt.xticks(rotation=90)
plt.show()

# %%
df['LikeCount'].value_counts()
# Out:
# 0      27141
# 1       9490
# 2       3873
# 3       2086
# 4       1241
#        ...
# 242        1
# 202        1
# 347        1
# 404        1
# 424        1
# Name: LikeCount, Length: 366, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(data=df, x='LikeCount',order=data.LikeCount.value_counts().index[:10])
plt.xticks(rotation=90)
plt.show()

# %%
df['QuoteCount'].value_counts()
# Out:
# 0       47665
# 1        1575
# 2         337
# 3         147
# 4          70
# 5          34
# 7          28
# 6          23
# 9          16
# 8          13
# 10         13
# 11         10
# 12          8
# 27          6
# 14          5
# 25          4
# 15          4
# 24          3
# 16          3
# 37          2
# 19          2
# 60          2
# 29          2
# 38          2
# 57          1
# 48          1
# 21          1
# 413         1
# 46          1
# 374         1
# 20          1
# 55          1
# 17          1
# 42          1
# 18          1
# 298         1
# 216         1
# 495         1
# 81          1
# 80          1
# 13          1
# 205         1
# 22          1
# 126         1
# 87          1
# 726         1
# 110         1
# 23          1
# 1947        1
# 45          1
# 456         1
# Name: QuoteCount, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(data=df, x='QuoteCount',order=data.QuoteCount.value_counts().index[:3])
plt.xticks(rotation=90)
plt.show()

# %%
df['Language'].value_counts()
# Out:
# en    32076
# ja     5046
# es     3315
# fr     2492
# de     1207
#       ...
# sd        1
# am        1
# hy        1
# or        1
# bn        1
# Name: Language, Length: 61, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(data=df, x='Language',order=data.Language.value_counts().index[:10])
plt.xticks(rotation=90)
plt.show()

# %%
df['Source'].unique()
# Out:
# array(['<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#        '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#        '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#        '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#        '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#        '<a href="https://nowtice.net/" rel="nofollow">nowtice_news</a>',
#        '<a href="https://smarterqueue.com" rel="nofollow">SmarterQueue</a>',
#        '<a href="https://github.com/M157q/py-feedr" rel="nofollow">py-feedr-M157q</a>',
#        '<a href="http://www.linkedin.com/" rel="nofollow">LinkedIn</a>',
#        '<a href="https://soccerstream.org/" rel="nofollow">testttewet</a>',
#        '<a href="http://publicize.wp.com/" rel="nofollow">Jetpack.com</a>',
# ...

# %%
plt.figure(figsize=(15,6))
sns.countplot(data=df, x='Source', order=df["Source"].value_counts().index[:10])
plt.xticks(rotation = 90)
plt.show()

# %%
df['hastag_counts'].unique()
# Out:
# array([ 0,  1,  2,  4, 11,  5,  3, 10, 15,  8, 12,  9,  6,  7, 13, 14, 16,
#        23, 20, 18, 21, 24, 22, 25, 17, 28, 19], dtype=int64)

# %%
df['hastag_counts'].value_counts()
# Out:
# 0     36414
# 1      5516
# 2      2772
# 3      1944
# 4      1150
# 5       651
# 6       396
# 7       295
# 8       229
# 9       124
# 10       98
# 13       76
# 11       69
# 12       51
# 15       44
# 16       43
# 14       41
# 18       25
# 17       14
# 23        9
# 19        9
# 25        8
# 21        7
# 20        7
# 24        6
# 22        2
# 28        1
# Name: hastag_counts, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(data=df, x='hastag_counts', order=df["hastag_counts"].value_counts().index[:10])
plt.xticks(rotation = 90)
plt.show()
